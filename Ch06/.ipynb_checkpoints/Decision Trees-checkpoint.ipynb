# %% [markdown]
# # Traing and Visualizing a Decison Tree

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
iris = load_iris()
X = iris.data[:, 2:]
y = iris.target

# %%
tree_clf = DecisionTreeClassifier(max_depth=2)
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
from sklearn.tree import export_graphviz
export_graphviz(
    tree_clf,
    out_file='iris_tree.dot',
    feature_names=iris.feature_names[2:],
    class_names= iris.target_names,
    rounded=True,
    filled=True
)

# %%
from IPython.display import Image
Image('iris_tree.png')

# %% [markdown]
# # Estimating Class Probabilities

# %%
tree_clf.predict_proba([[5, 1.5]])
# Out:
# array([[ 0.        ,  0.90740741,  0.09259259]])

# %%
tree_clf.predict([[5, 1.5]])
# Out:
# array([1])

# %% [markdown]
# # The CART Training Algorithm

# %% [markdown]
# ### Cost function
# $$
# J(k, t_k)=\frac{m_{left}}{m}G_{left}+\frac{m_{right}}{m}G_{right}
# $$

# %% [markdown]
# # Computational Complexity

# %% [markdown]
# - Train a model
#
# $O(n\times mlog(m)$
#
# - Making a Prediction
#
# $O(log_2(m))$

# %% [markdown]
# # Using Entropy criterion

# %%
tree_entropy_clf = DecisionTreeClassifier(criterion='entropy', max_depth=2)
tree_entropy_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
tree_clf.predict([[5, 1.5]])
# Out:
# array([1])

# %% [markdown]
# # Regularzation Hyperparameters

# %% [markdown]
# - max_depth
# - min_samples_split
# - min_sample_leaf
# - max_leaf_nodes
# - max_feaures
# - ...
#
# increasing min\_\* hyperparameters or reducing max\_\* hyperparameters will regularize the model

# %% [markdown]
# # Regression

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor(max_depth=2)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=2, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
from sklearn.tree import export_graphviz
export_graphviz(
    tree_reg,
    out_file='iris_tree_reg.dot',
    feature_names=iris.feature_names[2:],
    class_names= iris.target_names,
    rounded=True,
    filled=True
)

# %%
Image('iris_tree_reg.png')
